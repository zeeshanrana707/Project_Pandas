# %%
import pandas as pd
df = pd.read_csv("data.csv")
import matplotlib.pyplot as plt

# %%
df
# Out:
#     Country  2019_Complaints  2019_Losses  2020_Complaints  2020_Losses  \
# 0        PR              NaN    5929974.0             1338    7209755.0
# 1        PS           1784.0   22483591.0             2890   25423219.0
# 2        PT           1119.0   13870074.0             2020   12391290.0
# 3        PY           1913.0   10967865.0             2992          NaN
# 4        AE           5503.0   48101706.0             7390   81178182.0
# ..      ...              ...          ...              ...          ...
# 112      PE           4435.0   27363061.0             7339   27058091.0
# 113      PG            651.0    6153461.0             1016    6431254.0
# 114      PH           5688.0  179433874.0            10642  166452785.0
# 115      PK          28492.0  181705646.0            52024  200518146.0
# 116      PL          21903.0  390365695.0            42442  362788093.0
#
#      2021_Complaints  2021_Losses  2022_Complaints   2022_Losses  \
# ...

# %% [markdown]
# # Step 1: Analyze the Data from your dataset

# %%
df.head(10) # display the first 10 rows and by default it will display first 5 rows
# Out:
#   Country  2019_Complaints  2019_Losses  2020_Complaints  2020_Losses  \
# 0      PR              NaN    5929974.0             1338    7209755.0
# 1      PS           1784.0   22483591.0             2890   25423219.0
# 2      PT           1119.0   13870074.0             2020   12391290.0
# 3      PY           1913.0   10967865.0             2992          NaN
# 4      AE           5503.0   48101706.0             7390   81178182.0
# 5      AF            612.0          NaN             1095    8257595.0
# 6      AL           1261.0   15433066.0             2450   15481216.0
# 7      AM           2402.0   25413556.0             3290   38075278.0
# 8      AO            730.0    4218960.0             1471    4388316.0
# 9      AR           4555.0  106144702.0             6055   96414427.0
#
#    2021_Complaints  2021_Losses  2022_Complaints  2022_Losses  \
# 0             1785      9463928           1594.0   17211758.0
# 1             3352     48918464           3210.0          NaN
# ...

# %%
df.tail(10) # Display the last 10 rows and by default it will display the last 5 rows
# Out:
#     Country  2019_Complaints  2019_Losses  2020_Complaints  2020_Losses  \
# 107      NO           4031.0   45713939.0             6733   54542901.0
# 108      NP           1046.0    9903690.0             2207   11937086.0
# 109      NZ           1662.0   13317391.0             3713   18466612.0
# 110      OM           2814.0   14755487.0             3882   14987636.0
# 111      PA            963.0    6611775.0             1634    7821630.0
# 112      PE           4435.0   27363061.0             7339   27058091.0
# 113      PG            651.0    6153461.0             1016    6431254.0
# 114      PH           5688.0  179433874.0            10642  166452785.0
# 115      PK          28492.0  181705646.0            52024  200518146.0
# 116      PL          21903.0  390365695.0            42442  362788093.0
#
#      2021_Complaints  2021_Losses  2022_Complaints   2022_Losses  \
# 107            10130     64274074           9695.0  1.085409e+08
# ...

# %%
df.sample(10) # It displays 10 random rows
# Out:
#     Country  2019_Complaints   2019_Losses  2020_Complaints   2020_Losses  \
# 65       GT           3799.0  2.331076e+07             6358  2.629191e+07
# 39       CY            999.0  5.686522e+06             1706  6.853488e+06
# 38       TH          13088.0  1.220822e+08            24580  1.471262e+08
# 100      MX           6770.0  1.184457e+08            10216  1.444409e+08
# 40       CZ          30211.0  1.729912e+08            47442  2.125291e+08
# 0        PR              NaN  5.929974e+06             1338  7.209755e+06
# 42       DE          95136.0  1.559416e+09           148495  2.432408e+09
# 66       HK         113923.0  7.466138e+08           237997  8.234209e+08
# 18       BE           6275.0  6.131401e+07            10620  8.186829e+07
# 107      NO           4031.0  4.571394e+07             6733  5.454290e+07
#
#      2021_Complaints  2021_Losses  2022_Complaints   2022_Losses  \
# 65              4657     51948711           6416.0  5.310030e+07
# ...

# %%
# Maximum value in complaints of 2019
df['Complaints_19'].max()
# Out:
# 449305.0

# %%
# Minimum value in complaints of 2019
df['Complaints_19'].min()
# Out:
# 216.0

# %% [markdown]
# # Changing the Names of the Columns

# %%
df.rename(columns= {'2019_Complaints': 'Complaints_19', '2020_Complaints': 'Complaints_20', '2021_Complaints': 'Complaints_21', '2022_Complaints': 'Complaints_22', '2023_Complaints': 'Complaints_23', '2024_Complaints': 'Complaints_24' }, inplace=True)

# %%
df
# Out:
#     Country  Complaints_19  2019_Losses  Complaints_20  2020_Losses  \
# 0        PR            NaN    5929974.0           1338    7209755.0
# 1        PS         1784.0   22483591.0           2890   25423219.0
# 2        PT         1119.0   13870074.0           2020   12391290.0
# 3        PY         1913.0   10967865.0           2992          NaN
# 4        AE         5503.0   48101706.0           7390   81178182.0
# ..      ...            ...          ...            ...          ...
# 112      PE         4435.0   27363061.0           7339   27058091.0
# 113      PG          651.0    6153461.0           1016    6431254.0
# 114      PH         5688.0  179433874.0          10642  166452785.0
# 115      PK        28492.0  181705646.0          52024  200518146.0
# 116      PL        21903.0  390365695.0          42442  362788093.0
#
#      Complaints_21  2021_Losses  Complaints_22   2022_Losses  Complaints_23  \
# ...

# %%
# It displays the all the mathematical information about the data 
df.describe()
# Out:
#        Complaints_19   2019_Losses  Complaints_20   2020_Losses  \
# count     116.000000  1.160000e+02     117.000000  1.160000e+02
# mean    24857.232759  2.385975e+08   43248.495726  2.834871e+08
# std     64214.962177  5.104877e+08  112412.520213  6.060144e+08
# min       216.000000  2.498015e+06     362.000000  2.673181e+06
# 25%      1145.250000  1.237253e+07    1937.000000  1.391990e+07
# 50%      5309.500000  4.651015e+07    8187.000000  4.630231e+07
# 75%     16633.750000  2.032114e+08   28232.000000  2.165501e+08
# max    449305.000000  3.302745e+09  796395.000000  3.906715e+09
#
#        Complaints_21   2021_Losses  Complaints_22   2022_Losses  \
# count     117.000000  1.170000e+02     116.000000  1.140000e+02
# mean    45730.709402  4.712803e+08   43222.922414  7.368381e+08
# std    125357.179585  1.042951e+09  112509.786139  1.582783e+09
# min       391.000000  4.362630e+06     458.000000  6.648059e+06
# 25%      2102.000000  2.286356e+07    1915.500000  3.311023e+07
# ...

# %%
# Displays the information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117 entries, 0 to 116
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country        116 non-null    object
#  1   Complaints_19  116 non-null    float64
#  2   2019_Losses    116 non-null    float64
#  3   Complaints_20  117 non-null    int64
#  4   2020_Losses    116 non-null    float64
#  5   Complaints_21  117 non-null    int64
#  6   2021_Losses    117 non-null    int64
#  7   Complaints_22  116 non-null    float64
#  8   2022_Losses    114 non-null    float64
#  9   Complaints_23  117 non-null    int64
#  10  2023_Losses    117 non-null    int64
#  11  Complaints_24  116 non-null    float64
#  12  2024_Losses    117 non-null    int64
# dtypes: float64(6), int64(6), object(1)
# memory usage: 12.0+ KB

# %% [markdown]
# # Element Slicing using loc and iloc

# %%
# Single element slicing loc
df.loc[0, 'Country']
# Out:
# 'PR'

# %%
# Single element slicing using iloc
df.iloc[2, 3]
# Out:
# 2020

# %%
# Multiple element slicing using loc
# Select Multiple rows and columns
df.loc[0:3, 'Country': 'Complaints_20']
# Out:
#   Country  Complaints_19  2019_Losses  Complaints_20
# 0      PR            NaN    5929974.0           1338
# 1      PS         1784.0   22483591.0           2890
# 2      PT         1119.0   13870074.0           2020
# 3      PY         1913.0   10967865.0           2992

# %%
# Multiple element slicing using loc
# Select specific rows and columns
df.loc[[2, 4, 5], ['Country', 'Complaints_23']]
# Out:
#   Country  Complaints_23
# 2      PT           2178
# 4      AE          11034
# 5      AF           1150

# %%
#  Using .iloc for multiple rows or columns
# slicing range of rows anf columns
df.iloc[1:3, 0:2]
# Out:
#   Country  Complaints_19
# 1      PS         1784.0
# 2      PT         1119.0

# %%
# Using .iloc for multiple rows or columns
# Select specific rows and columns
df.iloc[[0, 2], [0,1]]
# Out:
#   Country  Complaints_19
# 0      PR            NaN
# 2      PT         1119.0

# %% [markdown]
# # Mean, Median and Mode

# %%
# Finding mean, median and mode of a specific element 
# Mean
df["Complaints_19"].mean()
# Out:
# 24857.23275862069

# %%
# Median
df["Complaints_19"].median()
# Out:
# 5309.5

# %%
# Mode
df["Complaints_19"].mode()
# Out:
# 0    612.0
# Name: Complaints_19, dtype: float64

# %% [markdown]
# # Data Cleaning

# %%
#Finding Null Values
# Check for Null Values
df.isnull()
# Out:
#      Country  Complaints_19  2019_Losses  Complaints_20  2020_Losses  \
# 0      False           True        False          False        False
# 1      False          False        False          False        False
# 2      False          False        False          False        False
# 3      False          False        False          False         True
# 4      False          False        False          False        False
# ..       ...            ...          ...            ...          ...
# 112    False          False        False          False        False
# 113    False          False        False          False        False
# 114    False          False        False          False        False
# 115    False          False        False          False        False
# 116    False          False        False          False        False
#
#      Complaints_21  2021_Losses  Complaints_22  2022_Losses  Complaints_23  \
# ...

# %%
#  Count Null Values
#  Count Null Values in each column
df.isnull().sum()
# Out:
# Country          1
# Complaints_19    1
# 2019_Losses      1
# Complaints_20    0
# 2020_Losses      1
# Complaints_21    0
# 2021_Losses      0
# Complaints_22    1
# 2022_Losses      3
# Complaints_23    0
# 2023_Losses      0
# Complaints_24    1
# 2024_Losses      0
# dtype: int64

# %%
# Count total null values in dataframe
df.isnull().sum().sum()
# Out:
# 9

# %%
# finding rows with null values
# Identify rows containing any null values
df.isnull().any(axis=1)
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# Length: 117, dtype: bool

# %%
# Identify rows where all columns are null
df.isnull().all(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 112    False
# 113    False
# 114    False
# 115    False
# 116    False
# Length: 117, dtype: bool

# %%
# Find Columns with Null Values
df.isnull().any()
# Out:
# Country           True
# Complaints_19     True
# 2019_Losses       True
# Complaints_20    False
# 2020_Losses       True
# Complaints_21    False
# 2021_Losses      False
# Complaints_22     True
# 2022_Losses       True
# Complaints_23    False
# 2023_Losses      False
# Complaints_24     True
# 2024_Losses      False
# dtype: bool

# %%
# Fill Null Values with Column Mean
# For a single element
df["Complaints_20"].fillna(df["Complaints_20"].mean())
# Out:
# 0       1338
# 1       2890
# 2       2020
# 3       2992
# 4       7390
#        ...
# 112     7339
# 113     1016
# 114    10642
# 115    52024
# 116    42442
# Name: Complaints_20, Length: 117, dtype: int64

# %%
# Group by relation
df.groupby('Country')['Complaints_20'].sum()
# Out:
# Country
# AE     7390
# AF     1095
# AL     2450
# AM     3290
# AO     1471
#       ...
# VG     1840
# VN    53039
# YE      362
# ZA    89172
# ZW      722
# Name: Complaints_20, Length: 116, dtype: int64

# %% [markdown]
# # Visualization

# %%
df.plot(kind='line') 
plt.show()

# %%
df.plot(kind='line', x='2019_Losses', y='Complaints_19', subplots=True)
plt.show()

# %%
df.plot(kind='hist', title='Histogrm Chart')
plt.show()
